# %% [markdown]
# ### 튜플 만들기

# %%
t1 = ()
t2 = (1,)
t3 = 1, 2, 3
t4 = 1, 

print(t3)
x, y, z = t3
print(x, y, z)
# Out:
# (1, 2, 3)
# 1 2 3

# %% [markdown]
# ### 튜플의 활용

# %%
x, y = 10, 20
x, y = y, x
print(x, y)
# Out:
# 20 10

# %%
def add_and_mul(a, b):
    return a+b, a*b

result = add_and_mul(3, 5)
print(result)
# Out:
# (8, 15)
